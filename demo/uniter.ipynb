# %%
定义 = '这是一个定义变量'
arr = [1,2,3,5,6,8,9,7,4,156,15,2]
stre = "{实打实}，{法法师}"
print(list(stre))
for index,item in enumerate(arr):
    print(item)
    print(index)
print(arr[2:4:1])
print(max(arr))
print(1 in arr)
print(1 not in arr)
print(f"my name is {定义}")
print(len(定义))
print(定义[1])
print(type(定义))
数组 = ['132','苹果','香蕉']
eat = '好吃吗？'
数组.append('芒果')
数组.remove('132')
print(type(数组))
print(数组)
数组.insert(1,'西瓜')
print(数组)
for t in 数组:
    print(t)
total = 0
for i in range(1,101):
    total = total + i
print(total)
numbers = []
for i  in range(1, 1000000+1):
    numbers.append(i)
print(sum(numbers))
# user_age = input('请输入您的年龄')
# print('您今年的年龄是'+user_age)
def function(parameter):
    print(parameter)
function(5555)
# 面向对象
# 定义类
class kind:
    def __init__(self, name):
        # 构造函数
        self.name = name
        print(123)
    def eat(self):
        # 定义方法
        print(self.name)
# 继承
# 子类如果init方法里调用不到父类的方法
# 解决办法是加super()返回当前类的父类
class kindson(kind):
    def __init__(self, name):
        super().__init__(name)
        # 构造函数
        self.name = name
name1 = kind('ddd')
name1.eat()
# assert 1+2>6,'错误信息'
user_input = input("请输入访客的名字")
with open("./aa.txt","a",encoding="utf-8") as f:
    while user_input != "q":
      try:
          user_height = float(input('请输入您的身高'))
          user_weight = float(input('请输入您的体重'))
          user_cales = user_height / user_weight ** 2
      except ValueError:
          print('格式错误')
      except ZeroDivisionError:
          print('除零错误')
      except:
          print('未知错误')
      else:
          print(str(user_cales))
      finally:
          print('已结束')
      f.write(user_input+'\n')
      print(f'欢迎{user_input}')
      user_input = input("请输入访客的名字")
# Out:
# ['{', '实', '打', '实', '}', '，', '{', '法', '法', '师', '}']
# [3, 5]
# 156
# True
# False
# my name is 这是一个定义变量
# 8
# 是
# <class 'str'>
# <class 'list'>
# ['苹果', '香蕉', '芒果']
# ['苹果', '西瓜', '香蕉', '芒果']
# 苹果
# 西瓜
# 香蕉
# 芒果
# 5050
# 500000500000
# 5555
# 123
# ddd
